# %%
# %pylab inline
# %autosave 50
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Autosaving every 50 seconds

# %%
reportEnv = dict(line.strip().split('=') for line in open('reportenv.properties'))

# %%
import os
sys.path.append(reportEnv['report.lib.path'])
import TradesReporter as tr
import pandas as pd
from IPython.display import HTML
import json
pd.set_option('notebook_repr_html',True)
pd.set_option('use_inf_as_null', True)
reload(tr)
# Out:
# <module 'TradesReporter' from 'e:/users/Ivan/vswsp/tl/Python/ReportLib\TradesReporter.pyc'>

# %%
root=os.getcwd()
with open(root + '/cfg.json') as data_file:    
    modelCfg = json.load(data_file)
simpleRun=modelCfg['ResearchMode']=='simpleRun'

# %%
display(tr.displayTitle('Model params'))
display(HTML( pd.DataFrame(pd.TimeSeries(modelCfg['CustomParams'])).to_html()))
# Out:
# <h3 align="center">Model params</h3>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>window</th>
#       <td> 25</td>
#     </tr>
#   </tbody>
# </table>

# %%
bs=tr.BacktestResults()
bs.load(root + '/trades.csv')
bs.plot_equity_d2d_for_ticker()
mc=tr.MetricsCalculator()
display(tr.displayTitle('Overall stat '))
mc.statToHtml(bs.trades)
# Out:
# <h3 align="center">Overall stat </h3>
#                          buyStat      sellStat
# HoldTimeMeanHours     234.191083    147.721925
# HoldTimeMedianHours    24.000000     24.000000
# cnt                   157.000000    187.000000
# max                  1487.000000   8875.000000
# mean                   34.852866     75.823529
# median                 -1.000000     -1.000000
# min                 -1225.000000  -1133.000000
# pf                      1.558979      2.275778
# pl                   5471.900000  14179.000000
# sharpe                  0.112887      0.106886

# %%
if len(bs.tickers()) > 1:
    for t in bs.tickers():
        bs.plot_equity_d2d_for_ticker(t)    
        display(tr.displayTitle('Stat for ' + t))
        display(mc.statToHtml(bs.trades[bs.trades.Ticker==t]))
# Out:
# <h3 align="center">Stat for EEM</h3>
#                          buyStat      sellStat
# HoldTimeMeanHours     697.469388    496.163265
# HoldTimeMedianHours   240.000000    192.000000
# cnt                    49.000000     49.000000
# max                  1487.000000   8875.000000
# mean                  128.428571    306.816327
# median                 64.000000    119.000000
# min                 -1225.000000  -1133.000000
# pf                      2.018450      3.689927
# pl                   6293.000000  15034.000000
# sharpe                  0.245435      0.228169
# <h3 align="center">Stat for RSX</h3>
#                         buyStat    sellStat
# HoldTimeMeanHours     24.000000   24.000000
# HoldTimeMedianHours   24.000000   24.000000
# cnt                  108.000000  138.000000
# max                  234.000000  398.000000
# mean                  -7.602778   -6.195652
# median                -1.000000   -1.000000
# min                 -318.000000 -576.000000
# pf                     0.772555    0.845249
# pl                  -821.100000 -855.000000
# sharpe                -0.082153   -0.051992

# %%
display(tr.displayTitle('Pnl/Factors'))
bs.plotFactors()
# Out:
# <h3 align="center">Pnl/Factors</h3>
# error HoldTimeHours

# %%
bs.plotSeasonalities()
display(tr.displayTitle('Seasonalities'))
# Out:
# <h3 align="center">Seasonalities</h3>
