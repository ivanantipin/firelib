# %%
# %pylab inline
# %autosave 50
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Autosaving every 50 seconds

# %%
reportEnv = dict(line.strip().split('=') for line in open('reportenv.properties'))

# %%
import os
sys.path.append(reportEnv['report.lib.path'])
import TradesReporter as tr
import pandas as pd
from IPython.display import HTML
import json
pd.set_option('notebook_repr_html',True)
pd.set_option('use_inf_as_null', True)
reload(tr)
# Out:
# <module 'TradesReporter' from '/home/ivan/IdeaProjects/firelib/./python/report/TradesReporter.pyc'>

# %%
root=os.getcwd()
with open(root + '/cfg.json') as data_file:    
    modelCfg = json.load(data_file)
simpleRun=modelCfg['backtestMode']['name'] == 'SimpleRun'

# %%
modelProps=dict(line.strip().split('=') for line in open('modelProps.properties')) 
display(tr.displayTitle('Model params'))
display(HTML( pd.DataFrame(pd.TimeSeries(modelProps)).to_html()))
# Out:
# <h3 align="center">Model params</h3>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>trading.hour</th>
#       <td> 10</td>
#     </tr>
#   </tbody>
# </table>

# %%
bs=tr.BacktestResults()
bs.load(root + '/trades.csv')
bs.plot_equity_d2d_for_ticker()
mc=tr.MetricsCalculator()
display(tr.displayTitle('Overall stat '))
mc.statToHtml(bs.trades)
# Out:
# <h3 align="center">Overall stat </h3>
#                          buyStat    sellStat
# HoldTimeMeanHours      41.217949   35.476471
# HoldTimeMedianHours    27.000000   24.000000
# cnt                   156.000000  170.000000
# max                   584.640000  532.000000
# mean                    8.914231    0.010235
# median                 -1.160000   -0.400000
# min                  -347.680000 -436.190000
# pf                      1.462840    1.000370
# pl                   1390.620000    1.740000
# sharpe                  0.106020    0.000116

# %%
if len(bs.tickers()) > 1:
    for t in bs.tickers():
        bs.plot_equity_d2d_for_ticker(t)    
        display(tr.displayTitle('Stat for ' + t))
        display(mc.statToHtml(bs.trades[bs.trades.Ticker==t]))
# Out:
# <h3 align="center">Stat for DIA</h3>
# /home/ivan/IdeaProjects/firelib/./python/report/TradesReporter.py:107: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead
#   tradesDF['HoldTimeHours'] = (tradesDF['ExitDate'] - tradesDF['EntryDate']).map(lambda x: x / np.timedelta64(1, 'h'))
#                          buyStat sellStat
# HoldTimeMeanHours      41.217949     None
# HoldTimeMedianHours    27.000000     None
# cnt                   156.000000     None
# max                   584.640000     None
# mean                    8.914231     None
# median                 -1.160000     None
# min                  -347.680000     None
# pf                      1.462840     None
# pl                   1390.620000     None
# sharpe                  0.106020     None
# <h3 align="center">Stat for SPY</h3>
#                     buyStat    sellStat
# HoldTimeMeanHours      None   35.476471
# HoldTimeMedianHours    None   24.000000
# cnt                    None  170.000000
# max                    None  532.000000
# mean                   None    0.010235
# median                 None   -0.400000
# min                    None -436.190000
# pf                     None    1.000370
# pl                     None    1.740000
# sharpe                 None    0.000116

# %%
display(tr.displayTitle('Pnl/Factors'))
bs.plotFactors()
# Out:
# <h3 align="center">Pnl/Factors</h3>
# error HoldTimeHours

# %%
bs.plotSeasonalities()
display(tr.displayTitle('Seasonalities'))
# Out:
# <h3 align="center">Seasonalities</h3>

# %%
if not simpleRun:    
    bs.loadOpts(root + '/Opt.csv')
    display(tr.displayTitle('Optimization'))
    bs.plotOptimization()
# Out:
# <h3 align="center">Optimization</h3>
